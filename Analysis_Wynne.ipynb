# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import yfinance as yf

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
crypt = CryptoCurrencies('YJZX5Q85CC6MRB2F', output_format = 'pandas')

# %%
btc_av = crypt.get_digital_currency_daily('BTC', market='USD')[0]
btc_av = pd.DataFrame(btc_av)
btc_av = btc_av[['1a. open (USD)', '2a. high (USD)', '3a. low (USD)', '4a. close (USD)', '5. volume']]
btc_av.columns = ['Open', 'High', 'Low', 'Close', 'Volume']
btc_av.index.names = ['Date']
btc_av
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2021-03-30  57635.46  57709.90  57405.23  57666.73    971.476679
# 2021-03-29  55777.65  58405.82  54800.01  57635.47  67857.937398
# 2021-03-28  55817.14  56559.75  54691.84  55777.63  39050.387511
# 2021-03-27  55025.59  56700.36  53950.00  55817.14  50105.475055
# 2021-03-26  51293.78  55073.46  51214.60  55025.59  63813.774692
# ...              ...       ...       ...       ...           ...
# 2018-07-09   6712.10   6802.06   6612.24   6662.12  26732.406550
# 2018-07-08   6753.48   6780.00   6667.44   6712.10  24622.947794
# 2018-07-07   6609.79   6818.16   6508.88   6756.98  23973.876886
# 2018-07-06   6529.20   6648.54   6425.00   6609.78  29397.094748
# 2018-07-05   6585.53   6712.00   6453.33   6529.20  35071.972898
#
# [1000 rows x 5 columns]

# %%
btc_yf = yf.download('BTC-USD', end='2018-06-26')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
btc_yf = btc_yf.drop(['Adj Close'], axis = 1)

# %%
btc_av = btc_av.iloc[::-1]
BTC = pd.concat([btc_yf, btc_av])

# %%
BTC = pd.DataFrame(BTC['Close'])
BTC.columns = ['^BTC']

# %%
BTC
# Out:
#                     ^BTC
# Date
# 2014-09-17    457.334015
# 2014-09-18    424.440002
# 2014-09-19    394.795990
# 2014-09-20    408.903992
# 2014-09-21    398.821014
# ...                  ...
# 2021-03-26  55025.590000
# 2021-03-27  55817.140000
# 2021-03-28  55777.630000
# 2021-03-29  57635.470000
# 2021-03-30  57666.730000
#
# [2378 rows x 1 columns]

# %%
NYA = yf.download(['^NYA'], start='2014-09-18', end='2021-03-22')
NYA = pd.DataFrame(NYA['Close'])
NYA.columns = ['^NYA']
NYA
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     ^NYA
# Date
# 2014-09-17  10973.740234
# 2014-09-18  11024.059570
# 2014-09-19  10989.570312
# 2014-09-22  10892.639648
# 2014-09-23  10815.419922
# ...                  ...
# 2021-03-15  15775.500000
# 2021-03-16  15669.299805
# 2021-03-17  15731.150391
# 2021-03-18  15589.089844
# 2021-03-19  15562.299805
#
# [1638 rows x 1 columns]

# %%
NSEI = yf.download(['^NSEI'], start='2014-09-18', end='2021-03-22')
NSEI = pd.DataFrame(NSEI['Close'])
NSEI.columns = ['^NSEI']
NSEI
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    ^NSEI
# Date
# 2014-09-17   7975.500000
# 2014-09-18   8114.750000
# 2014-09-19   8121.450195
# 2014-09-22   8146.299805
# 2014-09-23   8017.549805
# ...                  ...
# 2021-03-15  14929.500000
# 2021-03-16  14910.450195
# 2021-03-17  14721.299805
# 2021-03-18  14557.849609
# 2021-03-19  14744.000000
#
# [1592 rows x 1 columns]

# %%
N225 = yf.download(['^N225'], start='2014-09-17', end='2021-03-22')
N225 = pd.DataFrame(N225['Close'])
N225.columns = ['^N225']
N225
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    ^N225
# Date
# 2014-09-17  15888.669922
# 2014-09-18  16067.570312
# 2014-09-19  16321.169922
# 2014-09-22  16205.900391
# 2014-09-24  16167.450195
# ...                  ...
# 2021-03-15  29766.970703
# 2021-03-16  29921.089844
# 2021-03-17  29914.330078
# 2021-03-18  30216.750000
# 2021-03-19  29792.050781
#
# [1589 rows x 1 columns]

# %%
KS11 = yf.download(['^KS11'], start='2014-09-17', end='2021-03-22')
KS11 = pd.DataFrame(KS11['Close'])
KS11.columns = ['^KS11']
KS11
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   ^KS11
# Date
# 2014-09-17  2062.610107
# 2014-09-18  2047.739990
# 2014-09-19  2053.820068
# 2014-09-22  2039.270020
# 2014-09-23  2028.910034
# ...                 ...
# 2021-03-15  3045.709961
# 2021-03-16  3067.169922
# 2021-03-17  3047.500000
# 2021-03-18  3066.010010
# 2021-03-19  3039.530029
#
# [1592 rows x 1 columns]

# %%
IXIC = yf.download(['^IXIC'], start='2014-09-18', end='2021-03-22')
IXIC = pd.DataFrame(IXIC['Close'])
IXIC.columns = ['^IXIC']
IXIC
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    ^IXIC
# Date
# 2014-09-17   4562.189941
# 2014-09-18   4593.430176
# 2014-09-19   4579.790039
# 2014-09-22   4527.689941
# 2014-09-23   4508.689941
# ...                  ...
# 2021-03-15  13459.709961
# 2021-03-16  13471.570312
# 2021-03-17  13525.200195
# 2021-03-18  13116.169922
# 2021-03-19  13215.240234
#
# [1638 rows x 1 columns]

# %%
GSPTSE = yf.download(['^GSPTSE'], start='2014-09-18', end='2021-03-22')
GSPTSE = pd.DataFrame(GSPTSE['Close'])
GSPTSE.columns = ['^GSPTSE']
GSPTSE
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  ^GSPTSE
# Date
# 2014-09-17  15458.900391
# 2014-09-18  15465.500000
# 2014-09-19  15265.400391
# 2014-09-22  15129.000000
# 2014-09-23  15125.700195
# ...                  ...
# 2021-03-15  18954.800781
# 2021-03-16  18874.000000
# 2021-03-17  18983.099609
# 2021-03-18  18836.500000
# 2021-03-19  18854.000000
#
# [1633 rows x 1 columns]

# %%
GSPC = yf.download(['^GSPC'], start='2014-09-18', end='2021-03-22')
GSPC = pd.DataFrame(GSPC['Close'])
GSPC.columns = ['^GSPC']
GSPC
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   ^GSPC
# Date
# 2014-09-17  2001.569946
# 2014-09-18  2011.359985
# 2014-09-19  2010.400024
# 2014-09-22  1994.290039
# 2014-09-23  1982.770020
# ...                 ...
# 2021-03-15  3968.939941
# 2021-03-16  3962.709961
# 2021-03-17  3974.120117
# 2021-03-18  3915.459961
# 2021-03-19  3913.100098
#
# [1638 rows x 1 columns]

# %%
DJI = yf.download(['^DJI'], start='2014-09-18', end='2021-03-22')
DJI = pd.DataFrame(DJI['Close'])
DJI.columns = ['^DJI']
DJI
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     ^DJI
# Date
# 2014-09-17  17156.849609
# 2014-09-18  17265.990234
# 2014-09-19  17279.740234
# 2014-09-22  17172.679688
# 2014-09-23  17055.869141
# ...                  ...
# 2021-03-15  32953.460938
# 2021-03-16  32825.949219
# 2021-03-17  33015.371094
# 2021-03-18  32862.300781
# 2021-03-19  32627.970703
#
# [1638 rows x 1 columns]

# %%
BSESN = yf.download(['^BSESN'], start='2014-09-18', end='2021-03-22')
BSESN = pd.DataFrame(BSESN['Close'])
BSESN.columns = ['^BSESN']
BSESN
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   ^BSESN
# Date
# 2014-09-17  26631.289062
# 2014-09-18  27112.210938
# 2014-09-19  27090.419922
# 2014-09-22  27206.740234
# 2014-09-23  26775.689453
# ...                  ...
# 2021-03-15  50395.078125
# 2021-03-16  50363.960938
# 2021-03-17  49801.621094
# 2021-03-18  49216.519531
# 2021-03-19  49858.238281
#
# [1592 rows x 1 columns]

# %%
AXJO = yf.download(['^AXJO'], start='2014-09-18', end='2021-03-22')
AXJO = pd.DataFrame(AXJO['Close'])
AXJO.columns = ['^AXJO']
AXJO
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   ^AXJO
# Date
# 2014-09-18  5415.799805
# 2014-09-19  5433.100098
# 2014-09-22  5363.000000
# 2014-09-23  5415.700195
# 2014-09-24  5375.799805
# ...                 ...
# 2021-03-15  6773.000000
# 2021-03-16  6827.100098
# 2021-03-17  6795.200195
# 2021-03-18  6745.899902
# 2021-03-19  6708.200195
#
# [1646 rows x 1 columns]

# %%
f, axes = plt.subplots(3, 3, figsize=(24, 12))

sb.boxplot(data = BTC, orient = "h", ax = axes[0, 0])
sb.histplot(data = BTC, kde = True, ax = axes[0, 1])
sb.violinplot(data = BTC, orient = "h", ax = axes[0, 2])

sb.boxplot(data = NYA, orient = "h", ax = axes[1, 0])
sb.histplot(data = NYA, kde = True, ax = axes[1, 1])
sb.violinplot(data = NYA, orient = "h", ax = axes[1, 2])

sb.boxplot(data = NSEI, orient = "h", ax = axes[2, 0])
sb.histplot(data = NSEI, kde = True, ax = axes[2, 1])
sb.violinplot(data = NSEI, orient = "h", ax = axes[2, 2])
# Out:
# <AxesSubplot:>

# %%
f, axes = plt.subplots(3, 3, figsize=(24, 12))

sb.boxplot(data = N225, orient = "h", ax = axes[0, 0])
sb.histplot(data = N225, kde = True, ax = axes[0, 1])
sb.violinplot(data = N225, orient = "h", ax = axes[0, 2])

sb.boxplot(data = KS11, orient = "h", ax = axes[1, 0])
sb.histplot(data = KS11, kde = True, ax = axes[1, 1])
sb.violinplot(data = KS11, orient = "h", ax = axes[1, 2])

sb.boxplot(data = IXIC, orient = "h", ax = axes[2, 0])
sb.histplot(data = IXIC, kde = True, ax = axes[2, 1])
sb.violinplot(data = IXIC, orient = "h", ax = axes[2, 2])
# Out:
# <AxesSubplot:>

# %%
f, axes = plt.subplots(3, 3, figsize=(24, 12))

sb.boxplot(data = GSPTSE, orient = "h", ax = axes[0, 0])
sb.histplot(data = GSPTSE, kde = True, ax = axes[0, 1])
sb.violinplot(data = GSPTSE, orient = "h", ax = axes[0, 2])

sb.boxplot(data = GSPC, orient = "h", ax = axes[1, 0])
sb.histplot(data = GSPC, kde = True, ax = axes[1, 1])
sb.violinplot(data = GSPC, orient = "h", ax = axes[1, 2])

sb.boxplot(data = DJI, orient = "h", ax = axes[2, 0])
sb.histplot(data = DJI, kde = True, ax = axes[2, 1])
sb.violinplot(data = DJI, orient = "h", ax = axes[2, 2])
# Out:
# <AxesSubplot:>

# %%
f, axes = plt.subplots(2, 3, figsize=(24, 12))

sb.boxplot(data = BSESN, orient = "h", ax = axes[0, 0])
sb.histplot(data = BSESN, kde = True, ax = axes[0, 1])
sb.violinplot(data = BSESN, orient = "h", ax = axes[0, 2])

sb.boxplot(data = AXJO, orient = "h", ax = axes[1, 0])
sb.histplot(data = AXJO, kde = True, ax = axes[1, 1])
sb.violinplot(data = AXJO, orient = "h", ax = axes[1, 2])
# Out:
# <AxesSubplot:>

# %%
combined = pd.concat([BTC, AXJO, BSESN, DJI, GSPC, GSPTSE, IXIC, KS11, N225, NSEI, NYA ], join='inner', axis=1)

# %%
combined.head()
# Out:
#                   ^BTC        ^AXJO        ^BSESN          ^DJI        ^GSPC  \
# Date
# 2014-09-18  424.440002  5415.799805  27112.210938  17265.990234  2011.359985
# 2014-09-19  394.795990  5433.100098  27090.419922  17279.740234  2010.400024
# 2014-09-22  402.152008  5363.000000  27206.740234  17172.679688  1994.290039
# 2014-09-24  423.204987  5375.799805  26744.689453  17210.060547  1998.300049
# 2014-09-25  411.574005  5382.200195  26468.359375  16945.800781  1965.989990
#
#                  ^GSPTSE        ^IXIC        ^KS11         ^N225        ^NSEI  \
# Date
# 2014-09-18  15465.500000  4593.430176  2047.739990  16067.570312  8114.750000
# 2014-09-19  15265.400391  4579.790039  2053.820068  16321.169922  8121.450195
# 2014-09-22  15129.000000  4527.689941  2039.270020  16205.900391  8146.299805
# 2014-09-24  15120.500000  4555.220215  2035.640015  16167.450195  8002.399902
# 2014-09-25  14893.599609  4466.750000  2034.109985  16374.139648  7911.850098
#
# ...

# %%
combined.describe()
# Out:
#                ^BTC        ^AXJO        ^BSESN          ^DJI        ^GSPC  \
# count   1342.000000  1342.000000   1342.000000   1342.000000  1342.000000
# mean    6308.656439  5866.917217  33099.276973  22690.158493  2602.955179
# std     8713.822889   520.480503   6158.544071   4345.116439   509.998639
# min      178.102997  4546.000000  22976.000000  15666.440430  1859.329956
# 25%      454.946739  5468.000122  27836.057617  18057.910156  2108.875061
# 50%     4032.930000  5833.199951  32454.714844  23433.365234  2581.604980
# 75%     8914.797432  6179.500122  37551.035156  26079.297363  2907.814941
# max    58912.970000  7162.500000  52104.171875  33015.371094  3974.120117
#
#             ^GSPTSE         ^IXIC        ^KS11         ^N225         ^NSEI  \
# count   1342.000000   1342.000000  1342.000000   1342.000000   1342.000000
# mean   15408.747549   7093.806642  2184.914614  20653.684059   9980.657272
# std     1249.542270   2289.199091   261.416298   2904.475211   1737.275080
# ...

# %%
sb.pairplot(data = combined)
